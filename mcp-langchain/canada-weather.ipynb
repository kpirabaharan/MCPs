# %%
from env_canada import ECWeather

# %%
ajax_weather = ECWeather(coordinates=(43.8611, -79.0259))

# %%
await ajax_weather.update()

# %%
ajax_weather.conditions
# Out:
# {'temperature': {'label': 'Temperature', 'unit': 'C', 'value': 19.2},
#  'dewpoint': {'label': 'Dew Point', 'unit': 'C', 'value': 12.6},
#  'wind_chill': {'label': 'Wind Chill', 'value': None},
#  'humidex': {'label': 'Humidex', 'value': None},
#  'pressure': {'label': 'Pressure', 'unit': 'kPa', 'value': 100.1},
#  'tendency': {'label': 'Tendency', 'unit': 'kPa', 'value': None},
#  'humidity': {'label': 'Humidity', 'unit': '%', 'value': 66},
#  'visibility': {'label': 'Visibility', 'unit': 'km', 'value': 16.1},
#  'condition': {'label': 'Condition', 'value': 'Cloudy'},
#  'wind_speed': {'label': 'Wind Speed', 'unit': 'km/h', 'value': 17},
#  'wind_gust': {'label': 'Wind Gust', 'unit': 'km/h', 'value': 30},
#  'wind_dir': {'label': 'Wind Direction', 'value': 'SSE'},
#  'wind_bearing': {'label': 'Wind Bearing', 'unit': 'degrees', 'value': 150},
#  'high_temp': {'label': 'High Temperature', 'unit': 'C', 'value': 23},
# ...

# %%
ajax_weather.daily_forecasts
# Out:
# [{'period': 'Sunday',
#   'text_summary': 'Cloudy. Showers beginning this afternoon. Risk of a thunderstorm late this afternoon. Local amount 10 to 15 mm. Wind southeast 30 km/h gusting to 50. High 23. Humidex 28. UV index 3 or moderate.',
#   'icon_code': '19',
#   'temperature': 23,
#   'temperature_class': 'high',
#   'precip_probability': 0,
#   'timestamp': datetime.datetime(2025, 10, 19, 15, 0, tzinfo=tzutc())},
#  {'period': 'Sunday night',
#   'text_summary': 'Showers. Risk of a thunderstorm early this evening. Local amount 5 mm. Wind southwest 30 km/h gusting to 50 becoming northwest 30 gusting to 50 late this evening. Low 10.',
#   'icon_code': '19',
#   'temperature': 10,
#   'temperature_class': 'low',
#   'precip_probability': 0,
#   'timestamp': datetime.datetime(2025, 10, 19, 15, 0, tzinfo=tzutc())},
#  {'period': 'Monday',
# ...

# %%
ajax_weather.hourly_forecasts
# Out:
# [{'period': datetime.datetime(2025, 10, 19, 15, 0, tzinfo=tzutc()),
#   'condition': 'Mainly cloudy',
#   'temperature': 23,
#   'icon_code': '03',
#   'precip_probability': 20,
#   'wind_speed': 30,
#   'wind_direction': 'SE'},
#  {'period': datetime.datetime(2025, 10, 19, 16, 0, tzinfo=tzutc()),
#   'condition': 'Cloudy',
#   'temperature': 23,
#   'icon_code': '10',
#   'precip_probability': 20,
#   'wind_speed': 30,
#   'wind_direction': 'SE'},
#  {'period': datetime.datetime(2025, 10, 19, 17, 0, tzinfo=tzutc()),
#   'condition': 'Cloudy',
#   'temperature': 23,
#   'icon_code': '10',
#   'precip_probability': 20,
#   'wind_speed': 30,
#   'wind_direction': 'SE'},
#  {'period': datetime.datetime(2025, 10, 19, 18, 0, tzinfo=tzutc()),
#   'condition': 'Cloudy',
#   'temperature': 23,
#   'icon_code': '10',
#   'precip_probability': 20,
#   'wind_speed': 30,
#   'wind_direction': 'SE'},
#  {'period': datetime.datetime(2025, 10, 19, 19, 0, tzinfo=tzutc()),
# ...
